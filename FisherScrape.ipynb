# %% [markdown]
# <a href="https://colab.research.google.com/github/Valancinis/WranglingData/blob/main/FisherScrape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

login_url = 'https://www.fishersci.de/de/en/home.html'

data = {
    'username': '',
    'password': ''
}

with requests.Session() as s:
    response = requests.post(login_url , data)
    print(response.text)
    
    index_page= s.get('https://www.fishersci.de/shop/products/nalgene-square-petg-media-bottles-closure-sterile-shrink-wrapped-trays/10069012?searchHijack=true&searchTerm=342020-2000&searchType=RAPID&matchedCatNo=342020-2000&change_lang=true')
    soup = BeautifulSoup(index_page.text, 'html.parser')
    print(soup.prettify())
    
'''
url = "https://www.fishersci.de/shop/products/nalgene-square-petg-media-bottles-closure-sterile-shrink-wrapped-trays/10069012?searchHijack=true&searchTerm=342020-2000&searchType=RAPID&matchedCatNo=342020-2000&change_lang=true"
req = requests.get(url)
soup = BeautifulSoup(req.content, 'html.parser')
print(soup.prettify())
'''
# Out:
# <!doctype html><html class="no-js" lang="de"><head><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta http-equiv="content-type" content="text/html; charset=UTF-8"><meta name="viewport" content="width=device-width,initial-scale=1"><meta http-equiv="Last-Modified" content="13 May 2022 08:13:35 EDT"><meta name="title" content="Lab Equipment and Lab Supplies | Fisher Scientific"><meta name="description" content="Fisher Scientific is the UK's leading supplier of laboratory equipment, chemicals, and services used in scientific research, safety, healthcare, and education."><meta name="keywords" content=""><link rel="canonical" href="https://www.fishersci.de/de/de/home.html"/><link rel="alternate" href="https://www.fishersci.nl/nl/nl/home.html" hreflang="nl-NL"/><link rel="alternate" href="https://www.fishersci.es/es/en/home.html" hreflang="en-ES"/><link rel="alternate" href="https://www.fishersci.dk/dk/en/home.html" hreflang="en-DK"/><link rel="alternate" href="https://www.fishersci
# ...
